# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDS0321ENSkillsNetwork865-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>
#
# <h1 align=center><font size = 5>Assignment: SQL Notebook for Peer Assignment</font></h1>
#
# Estimated time needed: **60** minutes.
#
# ## Introduction
# Using this Python notebook you will:
#
# 1.  Understand the Spacex DataSet
# 2.  Load the dataset  into the corresponding table in a Db2 database
# 3.  Execute SQL queries to answer assignment questions

# %% [markdown]
# ## Overview of the DataSet
#
# SpaceX has gained worldwide attention for a series of historic milestones.
#
# It is the only private company ever to return a spacecraft from low-earth orbit, which it first accomplished in December 2010.
# SpaceX advertises Falcon 9 rocket launches on its website with a cost of 62 million dollars wheras other providers cost upward of 165 million dollars each, much of the savings is because Space X can reuse the first stage.
#
#
# Therefore if we can determine if the first stage will land, we can determine the cost of a launch.
#
# This information can be used if an alternate company wants to bid against SpaceX for a rocket launch.
#
# This dataset includes a record for each payload carried during a SpaceX mission into outer space.

# %% [markdown]
# ### Download the datasets
#
# This assignment requires you to load the spacex dataset.
#
# In many cases the dataset to be analyzed is available as a .CSV (comma separated values) file, perhaps on the internet. Click on the link below to download and save the dataset (.CSV file):
#
#  <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/data/Spacex.csv" target="_blank">Spacex DataSet</a>

# %% [markdown]
# **Navigate to the Go to UI screen**
#
# * Refer to this insruction in this <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sign%20up%20for%20IBM%20Cloud%20-%20Create%20Db2%20service%20instance%20-%20Get%20started%20with%20the%20Db2%20console/instructional-labs.md.html">link</a> for viewing  the   Go to UI screen.
#
#
# * Later click on **Data link(below SQL)**  in the Go to UI screen  and click on **Load Data** tab.
#
#
#
# * Later browse for the downloaded spacex file.
#
#
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/browsefile.png" width="800">
#
#
# * Once done select the schema andload the file.
#
#
#  <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/spacexload3.png" width="800">

# %% [markdown]
# If you are facing a problem in uploading the dataset (which is a csv file), you can follow the steps below to upload the .sql file instead of the CSV file:
#
# * Download the file <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/datasets/Spacex%20.sql">Spacex.sql</a>
#
# * Later click on **SQL** in the  **Go to UI Screen**.
#
# * Use the **From file** option to browse for the **SQL** file and upload it.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/sqlfile.png">
#
# * Once you upload the script,you can use the **Run All** option to run all the queries to insert the data.
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/runall.png">

# %%
# !pip install --force-reinstall ibm_db==3.1.0 ibm_db_sa==0.3.3
# !pip install sqlalchemy==1.3.9
# !pip uninstall ipython-sql -y
# !pip install ipython-sql==0.4.1
# Out:
# Collecting ibm_db==3.1.0
#   Downloading ibm_db-3.1.0.tar.gz (797 kB)
#      ------------------------------------- 797.3/797.3 kB 10.1 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Installing backend dependencies: started
#   Installing backend dependencies: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting ibm_db_sa==0.3.3
#   Downloading ibm_db_sa-0.3.3.tar.gz (24 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting sqlalchemy>=0.7.3
#   Downloading SQLAlchemy-2.0.9-cp39-cp39-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 63.1 MB/s eta 0:00:00
# Collecting greenlet!=0.4.17
#   Downloading greenlet-2.0.2-cp39-cp39-win_amd64.whl (192 kB)
#      ---------------------------------------- 192.1/192.1 kB ? eta 0:00:00
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Building wheels for collected packages: ibm_db, ibm_db_sa
#   Building wheel for ibm_db (pyproject.toml): started
#   Building wheel for ibm_db (pyproject.toml): finished with status 'done'
#   Created wheel for ibm_db: filename=ibm_db-3.1.0-py3-none-any.whl size=27687109 sha256=8a45b70d25b4809a4ee1235620d4f121b008ca8f1f3da4bd64f790457d35dd51
#   Stored in directory: c:\users\gregs\appdata\local\pip\cache\wheels\0a\dd\10\4a9ad59949e39786d729813e4bce24ccf2263c6d60a62de2f2
#   Building wheel for ibm_db_sa (setup.py): started
#   Building wheel for ibm_db_sa (setup.py): finished with status 'done'
#   Created wheel for ibm_db_sa: filename=ibm_db_sa-0.3.3-py3-none-any.whl size=27424 sha256=2cbd5a6dd1d7fa901eb0d024ac3e95a23522af48394abe71b9b2351ab0861cf7
#   Stored in directory: c:\users\gregs\appdata\local\pip\cache\wheels\8f\98\0c\930c68279890092297e12d4cc20e95613ddab15af6753d92bb
# Successfully built ibm_db ibm_db_sa
# Installing collected packages: ibm_db, typing-extensions, greenlet, sqlalchemy, ibm_db_sa
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.3.0
#     Uninstalling typing_extensions-4.3.0:
#       Successfully uninstalled typing_extensions-4.3.0
#   Attempting uninstall: greenlet
#     Found existing installation: greenlet 1.1.1
#     Uninstalling greenlet-1.1.1:
#       Successfully uninstalled greenlet-1.1.1
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
# Successfully installed greenlet-2.0.2 ibm_db-3.1.0 ibm_db_sa-0.3.3 sqlalchemy-2.0.9 typing-extensions-4.5.0
# Collecting sqlalchemy==1.3.9
#   Downloading SQLAlchemy-1.3.9.tar.gz (6.0 MB)
#      ---------------------------------------- 6.0/6.0 MB 12.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: sqlalchemy
#   Building wheel for sqlalchemy (setup.py): started
#   Building wheel for sqlalchemy (setup.py): finished with status 'done'
#   Created wheel for sqlalchemy: filename=SQLAlchemy-1.3.9-cp39-cp39-win_amd64.whl size=1163626 sha256=1f6eba2c2a7a17c3a0b4118d7141cc595b6285bb0978cd70db3fa0d4e96a3a02
#   Stored in directory: c:\users\gregs\appdata\local\pip\cache\wheels\5b\43\0d\de1699809f9e6aaa54a97275298fa07075cb19acc557b18955
# Successfully built sqlalchemy
# Installing collected packages: sqlalchemy
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 2.0.9
#     Uninstalling SQLAlchemy-2.0.9:
#       Successfully uninstalled SQLAlchemy-2.0.9
# Successfully installed sqlalchemy-1.3.9
# WARNING: Skipping ipython-sql as it is not installed.
# Collecting ipython-sql==0.4.1
#   Downloading ipython_sql-0.4.1-py3-none-any.whl (21 kB)
# Requirement already satisfied: ipython-genutils>=0.1.0 in c:\users\gregs\anaconda3\lib\site-packages (from ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: six in c:\users\gregs\anaconda3\lib\site-packages (from ipython-sql==0.4.1) (1.16.0)
# Collecting prettytable<1
#   Downloading prettytable-0.7.2.zip (28 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: ipython>=1.0 in c:\users\gregs\anaconda3\lib\site-packages (from ipython-sql==0.4.1) (7.31.1)
# Collecting sqlparse
#   Downloading sqlparse-0.4.3-py3-none-any.whl (42 kB)
#      ---------------------------------------- 42.8/42.8 kB ? eta 0:00:00
# Requirement already satisfied: sqlalchemy>=0.6.7 in c:\users\gregs\anaconda3\lib\site-packages (from ipython-sql==0.4.1) (1.3.9)
# Requirement already satisfied: setuptools>=18.5 in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (63.4.1)
# Requirement already satisfied: matplotlib-inline in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.1.6)
# Requirement already satisfied: pygments in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (2.11.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (3.0.20)
# Requirement already satisfied: decorator in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (5.1.1)
# Requirement already satisfied: backcall in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.2.0)
# Requirement already satisfied: traitlets>=4.2 in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.18.1)
# Requirement already satisfied: pickleshare in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.7.5)
# Requirement already satisfied: colorama in c:\users\gregs\anaconda3\lib\site-packages (from ipython>=1.0->ipython-sql==0.4.1) (0.4.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in c:\users\gregs\anaconda3\lib\site-packages (from jedi>=0.16->ipython>=1.0->ipython-sql==0.4.1) (0.8.3)
# Requirement already satisfied: wcwidth in c:\users\gregs\anaconda3\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=1.0->ipython-sql==0.4.1) (0.2.5)
# Building wheels for collected packages: prettytable
#   Building wheel for prettytable (setup.py): started
#   Building wheel for prettytable (setup.py): finished with status 'done'
#   Created wheel for prettytable: filename=prettytable-0.7.2-py3-none-any.whl size=13695 sha256=0284bdc4c173e05940df1d2f04ea106b7b9bd1c2bf1d9dae0a6b37d44495bc85
#   Stored in directory: c:\users\gregs\appdata\local\pip\cache\wheels\75\f7\28\77a076f1fa8cbeda61aca712815d04d7a32435f04a26a2dd7b
# Successfully built prettytable
# Installing collected packages: prettytable, sqlparse, ipython-sql
# Successfully installed ipython-sql-0.4.1 prettytable-0.7.2 sqlparse-0.4.3

# %% [markdown]
# ### Connect to the database
#
# Let us first load the SQL extension and establish a connection with the database

# %%
import ibm_db
import ibm_db_sa
import sqlalchemy

# %reload_ext sql

# %% [markdown]
# **DB2 magic in case of  UI service credentials.**
#
#
#
# <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DS0321EN-SkillsNetwork/labs/module_2/images/servicecredentials.png" width="600">
#
# * Use the following format.
#
# * Add security=SSL at the end
#
# **%sql ibm_db_sa://my-username:my-password@my-hostname:my-port/my-db-name?security=SSL**

# %%
dsn_hostname = "b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud" # e.g.: "dashdb-txn-sbox-yp-dal09-04.services.dal.bluemix.net"
dsn_uid = "ksp86402"        # e.g. "abc12345"
dsn_pwd = "hxU02343q04f4mRu"      # e.g. "7dBZ3wWt9XN6$o0J"

dsn_driver = "{IBM DB2 ODBC DRIVER}"
dsn_database = "BLUDB"            # e.g. "BLUDB"
dsn_port = "31249"                # e.g. "50000" 
dsn_protocol = "TCPIP"            # i.e. "TCPIP"

#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create the dsn connection string
dsn = (
    "DRIVER={0};"
    "DATABASE={1};"
    "HOSTNAME={2};"
    "PORT={3};"
    "PROTOCOL={4};"
    "UID={5};"
    "PWD={6};").format(dsn_driver, dsn_database, dsn_hostname, dsn_port, dsn_protocol, dsn_uid, dsn_pwd)

#print the connection string to check correct values are specified
print(dsn)

#DO NOT MODIFY THIS CELL. Just RUN it with Shift + Enter
#Create database connection
# Out:
# DRIVER={IBM DB2 ODBC DRIVER};DATABASE=BLUDB;HOSTNAME=b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud;PORT=31249;PROTOCOL=TCPIP;UID=ksp86402;PWD=hxU02343q04f4mRu;

# %%
# %sql ibm_db_sa://ksp86402:hxU02343q04f4mRu@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb?security=SSL

# %% [markdown]
# ## Tasks
#
# Now write and execute SQL queries to solve the assignment tasks.
#
# ### Task 1
#
#
#
#
# ##### Display the names of the unique launch sites  in the space mission

# %%
# %sql SELECT DISTINCT launch_site from SPACEX
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [('CCAFS LC-40',), ('CCAFS SLC-40',), ('KSC LC-39A',), ('VAFB SLC-4E',)]

# %% [markdown]
# ### Task 2
#
#
# #####  Display 5 records where launch sites begin with the string 'CCA'

# %%
# %sql SELECT launch_site from SPACEX WHERE launch_site LIKE 'CCA%' LIMIT 5
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',),
#  ('CCAFS LC-40',)]

# %%
# %sql SELECT * from spacex LIMIT 35
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [(datetime.date(2010, 6, 4), '18:45:00', 'F9 v1.0  B0003', 'CCAFS LC-40', 'Dragon Spacecraft Qualification Unit', 0, 'LEO', 'SpaceX', 'Success', 'Failure (parachute)'),
#  (datetime.date(2010, 12, 8), '15:43:00', 'F9 v1.0  B0004', 'CCAFS LC-40', 'Dragon demo flight C1, two CubeSats, barrel of Brouere cheese', 0, 'LEO (ISS)', 'NASA (COTS) NRO', 'Success', 'Failure (parachute)'),
#  (datetime.date(2012, 5, 22), '7:44:00', 'F9 v1.0  B0005', 'CCAFS LC-40', 'Dragon demo flight C2', 525, 'LEO (ISS)', 'NASA (COTS)', 'Success', 'No attempt'),
#  (datetime.date(2012, 10, 8), '0:35:00', 'F9 v1.0  B0006', 'CCAFS LC-40', 'SpaceX CRS-1', 500, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  (datetime.date(2013, 3, 1), '15:10:00', 'F9 v1.0  B0007', 'CCAFS LC-40', 'SpaceX CRS-2', 677, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'No attempt'),
#  (datetime.date(2013, 9, 29), '16:00:00', 'F9 v1.1  B1003', 'VAFB SLC-4E', 'CASSIOPE', 500, 'Polar LEO', 'MDA', 'Success', 'Uncontrolled (ocean)'),
#  (datetime.date(2013, 12, 3), '22:41:00', 'F9 v1.1', 'CCAFS LC-40', 'SES-8', 3170, 'GTO', 'SES', 'Success', 'No attempt'),
#  (datetime.date(2014, 1, 6), '22:06:00', 'F9 v1.1', 'CCAFS LC-40', 'Thaicom 6', 3325, 'GTO', 'Thaicom', 'Success', 'No attempt'),
#  (datetime.date(2014, 4, 18), '19:25:00', 'F9 v1.1', 'CCAFS LC-40', 'SpaceX CRS-3', 2296, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'Controlled (ocean)'),
#  (datetime.date(2014, 7, 14), '15:15:00', 'F9 v1.1', 'CCAFS LC-40', 'OG2 Mission 1  6 Orbcomm-OG2 satellites', 1316, 'LEO', 'Orbcomm', 'Success', 'Controlled (ocean)'),
#  (datetime.date(2014, 8, 5), '8:00:00', 'F9 v1.1', 'CCAFS LC-40', 'AsiaSat 8', 4535, 'GTO', 'AsiaSat', 'Success', 'No attempt'),
#  (datetime.date(2014, 9, 7), '5:00:00', 'F9 v1.1 B1011', 'CCAFS LC-40', 'AsiaSat 6', 4428, 'GTO', 'AsiaSat', 'Success', 'No attempt'),
#  (datetime.date(2014, 9, 21), '5:52:00', 'F9 v1.1 B1010', 'CCAFS LC-40', 'SpaceX CRS-4', 2216, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'Uncontrolled (ocean)'),
#  (datetime.date(2015, 1, 10), '9:47:00', 'F9 v1.1 B1012', 'CCAFS LC-40', 'SpaceX CRS-5', 2395, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'Failure (drone ship)'),
#  (datetime.date(2015, 2, 11), '23:03:00', 'F9 v1.1 B1013', 'CCAFS LC-40', 'DSCOVR', 570, 'HEO', 'U.S. Air Force NASA NOAA', 'Success', 'Controlled (ocean)'),
#  (datetime.date(2015, 3, 2), '3:50:00', 'F9 v1.1 B1014', 'CCAFS LC-40', 'ABS-3A Eutelsat 115 West B', 4159, 'GTO', 'ABS Eutelsat', 'Success', 'No attempt'),
#  (datetime.date(2015, 4, 14), '20:10:00', 'F9 v1.1 B1015', 'CCAFS LC-40', 'SpaceX CRS-6', 1898, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'Failure (drone ship)'),
#  (datetime.date(2015, 4, 27), '23:03:00', 'F9 v1.1 B1016', 'CCAFS LC-40', 'Turkmen 52 / MonacoSAT', 4707, 'GTO', 'Turkmenistan National Space Agency', 'Success', 'No attempt'),
#  (datetime.date(2015, 6, 28), '14:21:00', 'F9 v1.1 B1018', 'CCAFS LC-40', 'SpaceX CRS-7', 1952, 'LEO (ISS)', 'NASA (CRS)', 'Failure (in flight)', 'Precluded (drone ship)'),
#  (datetime.date(2015, 12, 22), '1:29:00', 'F9 FT B1019', 'CCAFS LC-40', 'OG2 Mission 2  11 Orbcomm-OG2 satellites', 2034, 'LEO', 'Orbcomm', 'Success', 'Success (ground pad)'),
#  (datetime.date(2016, 1, 17), '18:42:00', 'F9 v1.1 B1017', 'VAFB SLC-4E', 'Jason-3', 553, 'LEO', 'NASA (LSP) NOAA CNES', 'Success', 'Failure (drone ship)'),
#  (datetime.date(2016, 3, 4), '23:35:00', 'F9 FT B1020', 'CCAFS LC-40', 'SES-9', 5271, 'GTO', 'SES', 'Success', 'Failure (drone ship)'),
#  (datetime.date(2016, 4, 8), '20:43:00', 'F9 FT B1021.1', 'CCAFS LC-40', 'SpaceX CRS-8', 3136, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'Success (drone ship)'),
#  (datetime.date(2016, 5, 6), '5:21:00', 'F9 FT B1022', 'CCAFS LC-40', 'JCSAT-14', 4696, 'GTO', 'SKY Perfect JSAT Group', 'Success', 'Success (drone ship)'),
#  (datetime.date(2016, 5, 27), '21:39:00', 'F9 FT B1023.1', 'CCAFS LC-40', 'Thaicom 8', 3100, 'GTO', 'Thaicom', 'Success', 'Success (drone ship)'),
#  (datetime.date(2016, 6, 15), '14:29:00', 'F9 FT B1024', 'CCAFS LC-40', 'ABS-2A Eutelsat 117 West B', 3600, 'GTO', 'ABS Eutelsat', 'Success', 'Failure (drone ship)'),
#  (datetime.date(2016, 7, 18), '4:45:00', 'F9 FT B1025.1', 'CCAFS LC-40', 'SpaceX CRS-9', 2257, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'Success (ground pad)'),
#  (datetime.date(2016, 8, 14), '5:26:00', 'F9 FT B1026', 'CCAFS LC-40', 'JCSAT-16', 4600, 'GTO', 'SKY Perfect JSAT Group', 'Success', 'Success (drone ship)'),
#  (datetime.date(2017, 1, 14), '17:54:00', 'F9 FT B1029.1', 'VAFB SLC-4E', 'Iridium NEXT 1', 9600, 'Polar LEO', 'Iridium Communications', 'Success', 'Success (drone ship)'),
#  (datetime.date(2017, 2, 19), '14:39:00', 'F9 FT B1031.1', 'KSC LC-39A', 'SpaceX CRS-10', 2490, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'Success (ground pad)'),
#  (datetime.date(2017, 3, 16), '6:00:00', 'F9 FT B1030', 'KSC LC-39A', 'EchoStar 23', 5600, 'GTO', 'EchoStar', 'Success', 'No attempt'),
#  (datetime.date(2017, 3, 30), '22:27:00', 'F9 FT  B1021.2', 'KSC LC-39A', 'SES-10', 5300, 'GTO', 'SES', 'Success', 'Success (drone ship)'),
#  (datetime.date(2017, 5, 1), '11:15:00', 'F9 FT B1032.1', 'KSC LC-39A', 'NROL-76', 5300, 'LEO', 'NRO', 'Success', 'Success (ground pad)'),
#  (datetime.date(2017, 5, 15), '23:21:00', 'F9 FT B1034', 'KSC LC-39A', 'Inmarsat-5 F4', 6070, 'GTO', 'Inmarsat', 'Success', 'No attempt'),
#  (datetime.date(2017, 6, 3), '21:07:00', 'F9 FT B1035.1', 'KSC LC-39A', 'SpaceX CRS-11', 2708, 'LEO (ISS)', 'NASA (CRS)', 'Success', 'Success (ground pad)')]

# %% [markdown]
# ### Task 3
#
#
#
#
# ##### Display the total payload mass carried by boosters launched by NASA (CRS)

# %%
# %sql SELECT SUM(payload_mass_kg_) from spacex
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [(619967,)]

# %% [markdown]
# ### Task 4
#
#
#
#
# ##### Display average payload mass carried by booster version F9 v1.1

# %%
# %sql SELECT AVG(payload_mass_kg_) from spacex WHERE Booster_version LIKE 'F9 v1.1%'
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [(2534,)]

# %% [markdown]
# ### Task 5
#
# ##### List the date when the first successful landing outcome in ground pad was acheived.
#
#
# _Hint:Use min function_

# %%
# %sql SELECT MIN(Date) from spacex WHERE mission_outcome LIKE 'Success'
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [(datetime.date(2010, 6, 4),)]

# %% [markdown]
# ### Task 6
#
# ##### List the names of the boosters which have success in drone ship and have payload mass greater than 4000 but less than 6000

# %%
# %sql SELECT payload from spacex WHERE landing_outcome LIKE 'Success (drone%' AND payload_mass_kg_ BETWEEN 4000 AND 6000
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [('JCSAT-14',), ('JCSAT-16',), ('SES-10',), ('SES-11 / EchoStar 105',)]

# %% [markdown]
# ### Task 7
#
#
#
#
# ##### List the total number of successful and failure mission outcomes

# %%
# %%sql SELECT mission_outcome, COUNT(*)
# FROM spacex
# GROUP BY mission_outcome
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [('Failure (in flight)', 1),
#  ('Success', 99),
#  ('Success (payload status unclear)', 1)]

# %% [markdown]
# ### Task 8
#
#
#
# ##### List the   names of the booster_versions which have carried the maximum payload mass. Use a subquery

# %%
# %sql SELECT booster_version FROM spacex WHERE payload_mass_kg_ = (SELECT MAX(payload_mass_kg_) FROM spacex)
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [('F9 B5 B1048.4',),
#  ('F9 B5 B1049.4',),
#  ('F9 B5 B1051.3',),
#  ('F9 B5 B1056.4',),
#  ('F9 B5 B1048.5',),
#  ('F9 B5 B1051.4',),
#  ('F9 B5 B1049.5',),
#  ('F9 B5 B1060.2',),
#  ('F9 B5 B1058.3',),
#  ('F9 B5 B1051.6',),
#  ('F9 B5 B1060.3',),
#  ('F9 B5 B1049.7',)]

# %% [markdown]
# ### Task 9
#
#
# ##### List the failed landing_outcomes in drone ship, their booster versions, and launch site names for in year 2015

# %%
# %sql SELECT DATE, landing_outcome, booster_version, launch_site FROM spacex ORDER BY DATE LIMIT 25
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [(datetime.date(2010, 6, 4), 'Failure (parachute)', 'F9 v1.0  B0003', 'CCAFS LC-40'),
#  (datetime.date(2010, 12, 8), 'Failure (parachute)', 'F9 v1.0  B0004', 'CCAFS LC-40'),
#  (datetime.date(2012, 5, 22), 'No attempt', 'F9 v1.0  B0005', 'CCAFS LC-40'),
#  (datetime.date(2012, 10, 8), 'No attempt', 'F9 v1.0  B0006', 'CCAFS LC-40'),
#  (datetime.date(2013, 3, 1), 'No attempt', 'F9 v1.0  B0007', 'CCAFS LC-40'),
#  (datetime.date(2013, 9, 29), 'Uncontrolled (ocean)', 'F9 v1.1  B1003', 'VAFB SLC-4E'),
#  (datetime.date(2013, 12, 3), 'No attempt', 'F9 v1.1', 'CCAFS LC-40'),
#  (datetime.date(2014, 1, 6), 'No attempt', 'F9 v1.1', 'CCAFS LC-40'),
#  (datetime.date(2014, 4, 18), 'Controlled (ocean)', 'F9 v1.1', 'CCAFS LC-40'),
#  (datetime.date(2014, 7, 14), 'Controlled (ocean)', 'F9 v1.1', 'CCAFS LC-40'),
#  (datetime.date(2014, 8, 5), 'No attempt', 'F9 v1.1', 'CCAFS LC-40'),
#  (datetime.date(2014, 9, 7), 'No attempt', 'F9 v1.1 B1011', 'CCAFS LC-40'),
#  (datetime.date(2014, 9, 21), 'Uncontrolled (ocean)', 'F9 v1.1 B1010', 'CCAFS LC-40'),
#  (datetime.date(2015, 1, 10), 'Failure (drone ship)', 'F9 v1.1 B1012', 'CCAFS LC-40'),
#  (datetime.date(2015, 2, 11), 'Controlled (ocean)', 'F9 v1.1 B1013', 'CCAFS LC-40'),
#  (datetime.date(2015, 3, 2), 'No attempt', 'F9 v1.1 B1014', 'CCAFS LC-40'),
#  (datetime.date(2015, 4, 14), 'Failure (drone ship)', 'F9 v1.1 B1015', 'CCAFS LC-40'),
#  (datetime.date(2015, 4, 27), 'No attempt', 'F9 v1.1 B1016', 'CCAFS LC-40'),
#  (datetime.date(2015, 6, 28), 'Precluded (drone ship)', 'F9 v1.1 B1018', 'CCAFS LC-40'),
#  (datetime.date(2015, 12, 22), 'Success (ground pad)', 'F9 FT B1019', 'CCAFS LC-40'),
#  (datetime.date(2016, 1, 17), 'Failure (drone ship)', 'F9 v1.1 B1017', 'VAFB SLC-4E'),
#  (datetime.date(2016, 3, 4), 'Failure (drone ship)', 'F9 FT B1020', 'CCAFS LC-40'),
#  (datetime.date(2016, 4, 8), 'Success (drone ship)', 'F9 FT B1021.1', 'CCAFS LC-40'),
#  (datetime.date(2016, 5, 6), 'Success (drone ship)', 'F9 FT B1022', 'CCAFS LC-40'),
#  (datetime.date(2016, 5, 27), 'Success (drone ship)', 'F9 FT B1023.1', 'CCAFS LC-40')]

# %% [markdown]
# ### Task 10
#
# ##### Rank the count of landing outcomes (such as Failure (drone ship) or Success (ground pad)) between the date 2010-06-04 and 2017-03-20, in descending order

# %%
# %sql SELECT COUNT(*), landing_outcome FROM spacex GROUP BY landing_outcome ORDER BY COUNT(landing_outcome)
# Out:
#  * ibm_db_sa://ksp86402:***@b0aebb68-94fa-46ec-a1fc-1c999edb6187.c3n41cmd0nqnrk39u98g.databases.appdomain.cloud:31249/bludb
# Done.
# [(1, 'Precluded (drone ship)'),
#  (2, 'Failure (parachute)'),
#  (2, 'Uncontrolled (ocean)'),
#  (3, 'Failure'),
#  (5, 'Controlled (ocean)'),
#  (5, 'Failure (drone ship)'),
#  (9, 'Success (ground pad)'),
#  (14, 'Success (drone ship)'),
#  (22, 'No attempt'),
#  (38, 'Success')]

# %% [markdown]
# ### Reference Links
#
# * <a href ="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20String%20Patterns%20-%20Sorting%20-%20Grouping/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : String Patterns, Sorting and Grouping</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Built-in%20functions%20/Hands-on_Lab__Built-in_Functions.md.html?origin=www.coursera.org">Hands-on Lab: Built-in functions</a>
#
# *  <a  href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Labs_Coursera_V5/labs/Lab%20-%20Sub-queries%20and%20Nested%20SELECTs%20/instructional-labs.md.html?origin=www.coursera.org">Hands-on Lab : Sub-queries and Nested SELECT Statements</a>
#
# *   <a href="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-3-SQLmagic.ipynb">Hands-on Tutorial: Accessing Databases with SQL magic</a>
#
# *  <a href= "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DB0201EN-SkillsNetwork/labs/Module%205/DB0201EN-Week3-1-4-Analyzing.ipynb">Hands-on Lab: Analyzing a real World Data Set</a>

# %% [markdown]
# ## Author(s)
#
# <h4> Lakshmi Holla </h4>

# %% [markdown]
# ## Other Contributors
#
# <h4> Rav Ahuja </h4>

# %% [markdown]
# ## Change log
# | Date | Version | Changed by | Change Description |
# |------|--------|--------|---------|
# | 2021-10-12 | 0.4 |Lakshmi Holla | Changed markdown|
# | 2021-08-24 | 0.3 |Lakshmi Holla | Added library update|
# | 2021-07-09 | 0.2 |Lakshmi Holla | Changes made in magic sql|
# | 2021-05-20 | 0.1 |Lakshmi Holla | Created Initial Version |

# %% [markdown]
# ## <h3 align="center"> © IBM Corporation 2021. All rights reserved. <h3/>
